# %%
from lib2to3.pgen2.pgen import DFAState
from hdf5_getters import open_h5_file_read
from data_helpers import get_total_features, load_song_data

# %% [markdown]
# The below extension needs to be activated to show the progress bar

# %%
# !jupyter nbextension enable --py widgetsnbextension --sys-prefix
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
PATH_R = "../MillionSongSubset"
PATH_HDF5 = "../sample_data/TRAXLZU12903D05F94.h5"

regex_half = {1: "[A-M]", 2: "[N-Z]"}

colsPart = {}
colsPart[1] = [
    "artist_latitude",
    "artist_longitude",
    "artist_terms",
    "artist_terms_weight",
    "year",
]
colsPart[2] = [
    "artist_hotttnesss",
    "artist_name",
    "artist_terms",
    "artist_terms_weight",
    "loudness",
    "song_hotttnesss",
    "tempo",
    "year",
    "title",
    "X_mean",
    "X_std",
    "X_skew",
    "X_kurtosis",
    "X_median",
]

# %%
df = load_song_data(letter="A", half=1, path_r=PATH_R, path_hdf5=PATH_HDF5, max_songs=None)
# Out:
#   0%|          | 0/3813 [00:00<?, ?it/s]
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# attr is: nan
# is Array
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3813 entries, 0 to 3812
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   analysis_sample_rate        3813 non-null   int32
#  1   artist_7digitalid           3813 non-null   int32
#  2   artist_familiarity          3811 non-null   float64
#  3   artist_hotttnesss           3813 non-null   float64
#  4   artist_id                   3813 non-null   object
#  5   artist_latitude             1392 non-null   float64
#  6   artist_location             3813 non-null   object
#  7   artist_longitude            1392 non-null   float64
#  8   artist_mbid                 3813 non-null   object
#  9   artist_mbtags               1397 non-null   object
#  10  artist_mbtags_count         1397 non-null   object
#  11  artist_name                 3813 non-null   object
#  12  artist_playmeid             3813 non-null   int32
# ...

# %%
df.head(1)
# Out:
#    analysis_sample_rate  artist_7digitalid  artist_familiarity  \
# 0                 22050              68182            0.552705
#
#    artist_hotttnesss           artist_id  artist_latitude artist_location  \
# 0           0.387008  AR9A5TK1187B9AD07F              NaN
#
#    artist_longitude                           artist_mbid artist_mbtags  ...  \
# 0               NaN  33e09dd8-a998-4e1a-9e69-1a6567a3803d            []  ...
#
#   start_of_fade_out                                  tatums_confidence  \
# 0            68.598  [0.463, 0.467, 0.473, 0.482, 0.494, 0.506, 0.4...
#
#                                         tatums_start    tempo time_signature  \
# 0  [0.05795, 0.2264, 0.39569, 0.5582, 0.72664, 0....  177.093              1
#
#   time_signature_confidence                    title track_7digitalid  \
# 0                     0.266  Tien An Man Dream Again          3152108
#
#              track_id  year
# 0  TRADPQW128F42636C3  1991
#
# [1 rows x 54 columns]

# %%
df[:1].to_json("head1.json", orient="records")

# %%
df[df["song_hotttnesss"].isnull()]["song_hotttnesss"]
# Out:
# 1     NaN
# 2     NaN
# 4     NaN
# 5     NaN
# 6     NaN
#        ..
# 483   NaN
# 485   NaN
# 487   NaN
# 488   NaN
# 493   NaN
# Name: song_hotttnesss, Length: 211, dtype: float64
